# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("dataset.tsv", sep="\t")

# %%
data
# Out:
#     donor_is_old    BMI    WBC Neutrophils  Lymphocytes  Monocytes  \
# 0          False  False  False       False        False      False
# 1          False   True  False       False        False      False
# 2          False   True   True        True         True      False
# 3          False  False  False       False        False      False
# 4          False   True  False       False        False      False
# 5          False  False  False       False        False      False
# 6          False  False   True       False         True      False
# 7          False  False  False         NaN         True      False
# 8          False  False  False       False        False      False
# 9          False  False  False       False        False      False
# 10         False   True  False       False         True      False
# 11         False  False   True       False         True       True
# 12         False  False  False       False         True      False
# ...

# %%
#odczyt regół i ich lekka obróbka
rules = []
with open('rules.txt', 'r', encoding='utf-8') as file:
    for line in file:
        rules.append(line.strip())
cleaned_rules = [i.replace(" => donor_is_old", "") for i in rules]
